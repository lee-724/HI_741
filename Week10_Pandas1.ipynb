# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Series

# %% [markdown]
# A Series is a one-dimensional array-like object containing a sequence of values (of similar types to NumPy types) of the same type and an associated array of data labels, called its index. The simplest Series is formed from only an array of data:

# %%
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
# you can specify the index of the series yourself
obj2 = pd.Series([4, 7, -5, 3], index=["d", "b", "a", "c"])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
# accessing the index
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
# converting a pandas series to a Python dictionary
obj2.to_dict()
# Out:
# {'d': 4, 'b': 7, 'a': -5, 'c': 3}

# %% [markdown]
# #### Data frame

# %% [markdown]
# A DataFrame represents a rectangular table of data and contains an ordered, named collection of columns, each of which can be a different value type (numeric, string, Boolean, etc.). The DataFrame has both a row and column index; it can be thought of as a dictionary of Series all sharing the same index.

# %% [markdown]
# ##### Creating a data frame

# %%
# From a dictionary 
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
# key = state, year, pop
frame = pd.DataFrame(data)
# didn't specify an index so starts at 0
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.state.value_counts() # count for different values
# Out:
# state
# Ohio      3
# Nevada    3
# Name: count, dtype: int64

# %%
frame.head(3) # specifing how many rows to print
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5
# 1  Ohio  2001  1.7
# 2  Ohio  2002  3.6

# %%
frame.tail(3) # last rows to print
# Out:
#     state  year  pop
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
# Rows can also be retrieved by position or name with the special iloc and loc attribute
# Label-based indexing
# df.loc[row_label, column_label]
frame.loc[0]
# Out:
# state    Ohio
# year     2000
# pop       1.5
# Name: 0, dtype: object

# %%
frame.loc[0, "year"]
# Out:
# np.int64(2000)

# %%
# Integer-based indexing
frame.iloc[1]
# Out:
# state    Ohio
# year     2001
# pop       1.7
# Name: 1, dtype: object

# %%
# removing columns using del
del frame["pop"]

# %%
frame
# Out:
#     state  year
# 0    Ohio  2000
# 1    Ohio  2001
# 2    Ohio  2002
# 3  Nevada  2001
# 4  Nevada  2002
# 5  Nevada  2003

# %%
frame.columns
# Out:
# Index(['state', 'year'], dtype='object')

# %%
# You can conviniently convert the column names to a list
list(frame.columns)
# Out:
# ['state', 'year']

# %%
# transposing a data frame: swapping the rows and columns
frame.T
# Out:
#           0     1     2       3       4       5
# state  Ohio  Ohio  Ohio  Nevada  Nevada  Nevada
# year   2000  2001  2002    2001    2002    2003

# %%
obj = pd.Series(np.arange(4.), index=["a", "b", "c", "d"])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj["b"]
# Out:
# np.float64(1.0)

# %%
obj.iloc[1]
# Out:
# np.float64(1.0)

# %%
obj[2:4]
# Out:
# c    2.0
# d    3.0
# dtype: float64

# %%
obj[["b", "a", "d"]]
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %%
obj[obj < 2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
obj.loc[["b", "a", "d"]]
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %% [markdown]
# #### Reading and writing files using Pandas

# %%
df = pd.read_csv("ex1.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df = pd.read_csv("ex1.csv")
#       2 df.head()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
# reading in a file without a header
df2 = pd.read_csv("ex2.csv", header=None)
df2.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 2
#       1 # reading in a file without a header
# ----> 2 df2 = pd.read_csv("ex2.csv", header=None)
#       3 df2.head()
#
# ...

# %%
# we can manually pass in a header for the data frame
pd.read_csv("ex2.csv", names=["a", "b", "c", "d", "message"])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
names = ["a", "b", "c", "d", "message"]
pd.read_csv("ex2.csv", names=names, index_col="message") # indexing using the message column
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
df2.to_csv("df2.csv")

# %% [markdown]
# #### Handling missing data

# %%
float_data = pd.Series([1.2, -3.5, np.nan, 0])
float_data
# Out:
# 0    1.2
# 1   -3.5
# 2    NaN
# 3    0.0
# dtype: float64

# %%
# The isna method gives us a Boolean Series with True where values are null
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
# You can drop the NAs 
data = pd.Series([1, np.nan, 3.5, np.nan, 7])
data
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64

# %%
data = data.dropna() # will delete rows with the missng values
data
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
# same as 
data = data[data.notna()]
data
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
df = pd.DataFrame(np.random.standard_normal((7, 3)))
df.iloc[:4, 1] = np.nan
df
# Out:
#           0         1         2
# 0 -1.285744       NaN  0.817303
# 1  0.319058       NaN -0.828427
# 2 -0.387612       NaN  0.573499
# 3  1.142504       NaN -0.316616
# 4  0.951941  0.899539  0.464085
# 5  0.837988  0.277375  0.444856
# 6  0.960052  1.031553  0.852791

# %%
# you can also fill in the missing values
df = df.fillna(0)
df
# Out:
#           0         1         2
# 0 -0.707290  0.000000  0.731904
# 1  0.775830  0.000000  0.403277
# 2 -0.057809  0.000000  0.316385
# 3  0.179403  0.000000 -1.386033
# 4  0.893055 -0.781747 -0.343307
# 5  1.447994 -0.402365 -1.381169
# 6 -0.114869  0.578260  0.455558

# %% [markdown]
# #### Removing duplicates

# %%
data = pd.DataFrame({"k1": ["one", "two"] * 3 + ["two"], "k2": [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
# The DataFrame method duplicated returns a Boolean Series indicating whether each row is a duplicate (its column values are exactly equal to those in an earlier row) or not:
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data = data.drop_duplicates()
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
